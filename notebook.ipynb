# %%
import pandas as pd


data = pd.read_csv("CNN_time_threshold_analysis_results.csv")

point_5 = data[data['Threshold']==0.5]

point_5
# Out:
#       Unnamed: 0  Time  Threshold   TN    FP    FN     TP
# 9              9     1        0.5  972  7176   732  11347
# 28            28     2        0.5  332  6542   273  11210
# 47            47     3        0.5  791  5327   890  10082
# 66            66     4        0.5  795  4757  1105   9453
# 85            85     5        0.5  280  4771   361   9750
# 104          104     6        0.5  334  4289   533   9160
# 123          123     7        0.5  144  4130   212   9049
# 142          142     8        0.5  254  3732   391   8543
# 161          161     9        0.5  405  3321   736   7856
# 180          180    10        0.5  177  3286   288   7996
# 199          199    11        0.5   92  3147   152   7813
# 218          218    12        0.5  148  2859   219   7449
# 237          237    13        0.5   75  2732   158   7242
# 256          256    14        0.5   21  2606    20   7114
# 275          275    15        0.5   28  2420    30   6821
# ...
